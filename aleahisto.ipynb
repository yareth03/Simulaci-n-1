# %% [markdown]
# <a href="https://colab.research.google.com/github/yareth03/Simulaci-n-1/blob/main/aleahisto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tabulate import tabulate
import matplotlib.pyplot as plt
def randomyare():
    xi = int(input("Escribe el valor inicial: "))
    a = int(input("Escribe el multiplicador constante: "))
    c = int(input("Escribe el incremento: "))
    #m = int(input("Escribe el modulo: "))
    m= 10^2
    n = int(input("¿Cuántas iteraciones quieres? "))
    tabla = [ ]
    Lista = []
    p = 0


    for i in range(1, n + 1):

        xi = (a * xi + c) % m
        p = float(xi)
        tabla.append([i, xi, xi/m])
        Lista.append([xi/m])



    return tabla,n, Lista


tb, n, listaa = randomyare()
print(tabulate(tb, tablefmt="grid"))
plt.plot(listaa)
# Out:
# Escribe el valor inicial: 5
# Escribe el multiplicador constante: 81
# Escribe el incremento: 89
# ¿Cuántas iteraciones quieres? 278
# +-----+---+-------+
# |   1 | 6 | 0.75  |
# +-----+---+-------+
# |   2 | 7 | 0.875 |
# +-----+---+-------+
# |   3 | 0 | 0     |
# +-----+---+-------+
# |   4 | 1 | 0.125 |
# +-----+---+-------+
# |   5 | 2 | 0.25  |
# +-----+---+-------+
# |   6 | 3 | 0.375 |
# +-----+---+-------+
# |   7 | 4 | 0.5   |
# +-----+---+-------+
# |   8 | 5 | 0.625 |
# +-----+---+-------+
# |   9 | 6 | 0.75  |
# +-----+---+-------+
# |  10 | 7 | 0.875 |
# +-----+---+-------+
# |  11 | 0 | 0     |
# +-----+---+-------+
# |  12 | 1 | 0.125 |
# +-----+---+-------+
# |  13 | 2 | 0.25  |
# +-----+---+-------+
# |  14 | 3 | 0.375 |
# +-----+---+-------+
# |  15 | 4 | 0.5   |
# +-----+---+-------+
# |  16 | 5 | 0.625 |
# +-----+---+-------+
# |  17 | 6 | 0.75  |
# +-----+---+-------+
# |  18 | 7 | 0.875 |
# +-----+---+-------+
# |  19 | 0 | 0     |
# +-----+---+-------+
# |  20 | 1 | 0.125 |
# +-----+---+-------+
# |  21 | 2 | 0.25  |
# +-----+---+-------+
# |  22 | 3 | 0.375 |
# +-----+---+-------+
# |  23 | 4 | 0.5   |
# +-----+---+-------+
# |  24 | 5 | 0.625 |
# +-----+---+-------+
# |  25 | 6 | 0.75  |
# +-----+---+-------+
# |  26 | 7 | 0.875 |
# +-----+---+-------+
# |  27 | 0 | 0     |
# +-----+---+-------+
# |  28 | 1 | 0.125 |
# +-----+---+-------+
# |  29 | 2 | 0.25  |
# +-----+---+-------+
# |  30 | 3 | 0.375 |
# +-----+---+-------+
# |  31 | 4 | 0.5   |
# +-----+---+-------+
# |  32 | 5 | 0.625 |
# +-----+---+-------+
# |  33 | 6 | 0.75  |
# +-----+---+-------+
# |  34 | 7 | 0.875 |
# +-----+---+-------+
# |  35 | 0 | 0     |
# +-----+---+-------+
# |  36 | 1 | 0.125 |
# +-----+---+-------+
# |  37 | 2 | 0.25  |
# +-----+---+-------+
# |  38 | 3 | 0.375 |
# +-----+---+-------+
# |  39 | 4 | 0.5   |
# +-----+---+-------+
# |  40 | 5 | 0.625 |
# +-----+---+-------+
# |  41 | 6 | 0.75  |
# +-----+---+-------+
# |  42 | 7 | 0.875 |
# +-----+---+-------+
# |  43 | 0 | 0     |
# +-----+---+-------+
# |  44 | 1 | 0.125 |
# +-----+---+-------+
# |  45 | 2 | 0.25  |
# +-----+---+-------+
# |  46 | 3 | 0.375 |
# +-----+---+-------+
# |  47 | 4 | 0.5   |
# +-----+---+-------+
# |  48 | 5 | 0.625 |
# +-----+---+-------+
# |  49 | 6 | 0.75  |
# +-----+---+-------+
# |  50 | 7 | 0.875 |
# +-----+---+-------+
# |  51 | 0 | 0     |
# +-----+---+-------+
# |  52 | 1 | 0.125 |
# +-----+---+-------+
# |  53 | 2 | 0.25  |
# +-----+---+-------+
# |  54 | 3 | 0.375 |
# +-----+---+-------+
# |  55 | 4 | 0.5   |
# +-----+---+-------+
# |  56 | 5 | 0.625 |
# +-----+---+-------+
# |  57 | 6 | 0.75  |
# +-----+---+-------+
# |  58 | 7 | 0.875 |
# +-----+---+-------+
# |  59 | 0 | 0     |
# +-----+---+-------+
# |  60 | 1 | 0.125 |
# +-----+---+-------+
# |  61 | 2 | 0.25  |
# +-----+---+-------+
# |  62 | 3 | 0.375 |
# +-----+---+-------+
# |  63 | 4 | 0.5   |
# +-----+---+-------+
# |  64 | 5 | 0.625 |
# +-----+---+-------+
# |  65 | 6 | 0.75  |
# +-----+---+-------+
# |  66 | 7 | 0.875 |
# +-----+---+-------+
# |  67 | 0 | 0     |
# +-----+---+-------+
# |  68 | 1 | 0.125 |
# +-----+---+-------+
# |  69 | 2 | 0.25  |
# +-----+---+-------+
# |  70 | 3 | 0.375 |
# +-----+---+-------+
# |  71 | 4 | 0.5   |
# +-----+---+-------+
# |  72 | 5 | 0.625 |
# +-----+---+-------+
# |  73 | 6 | 0.75  |
# +-----+---+-------+
# |  74 | 7 | 0.875 |
# +-----+---+-------+
# |  75 | 0 | 0     |
# +-----+---+-------+
# |  76 | 1 | 0.125 |
# +-----+---+-------+
# |  77 | 2 | 0.25  |
# +-----+---+-------+
# |  78 | 3 | 0.375 |
# +-----+---+-------+
# |  79 | 4 | 0.5   |
# +-----+---+-------+
# |  80 | 5 | 0.625 |
# +-----+---+-------+
# |  81 | 6 | 0.75  |
# +-----+---+-------+
# |  82 | 7 | 0.875 |
# +-----+---+-------+
# |  83 | 0 | 0     |
# +-----+---+-------+
# |  84 | 1 | 0.125 |
# +-----+---+-------+
# |  85 | 2 | 0.25  |
# +-----+---+-------+
# |  86 | 3 | 0.375 |
# +-----+---+-------+
# |  87 | 4 | 0.5   |
# +-----+---+-------+
# |  88 | 5 | 0.625 |
# +-----+---+-------+
# |  89 | 6 | 0.75  |
# +-----+---+-------+
# |  90 | 7 | 0.875 |
# +-----+---+-------+
# |  91 | 0 | 0     |
# +-----+---+-------+
# |  92 | 1 | 0.125 |
# +-----+---+-------+
# |  93 | 2 | 0.25  |
# +-----+---+-------+
# |  94 | 3 | 0.375 |
# +-----+---+-------+
# |  95 | 4 | 0.5   |
# +-----+---+-------+
# |  96 | 5 | 0.625 |
# +-----+---+-------+
# |  97 | 6 | 0.75  |
# +-----+---+-------+
# |  98 | 7 | 0.875 |
# +-----+---+-------+
# |  99 | 0 | 0     |
# +-----+---+-------+
# | 100 | 1 | 0.125 |
# +-----+---+-------+
# | 101 | 2 | 0.25  |
# +-----+---+-------+
# | 102 | 3 | 0.375 |
# +-----+---+-------+
# | 103 | 4 | 0.5   |
# +-----+---+-------+
# | 104 | 5 | 0.625 |
# +-----+---+-------+
# | 105 | 6 | 0.75  |
# +-----+---+-------+
# | 106 | 7 | 0.875 |
# +-----+---+-------+
# | 107 | 0 | 0     |
# +-----+---+-------+
# | 108 | 1 | 0.125 |
# +-----+---+-------+
# | 109 | 2 | 0.25  |
# +-----+---+-------+
# | 110 | 3 | 0.375 |
# +-----+---+-------+
# | 111 | 4 | 0.5   |
# +-----+---+-------+
# | 112 | 5 | 0.625 |
# +-----+---+-------+
# | 113 | 6 | 0.75  |
# +-----+---+-------+
# | 114 | 7 | 0.875 |
# +-----+---+-------+
# | 115 | 0 | 0     |
# +-----+---+-------+
# | 116 | 1 | 0.125 |
# +-----+---+-------+
# | 117 | 2 | 0.25  |
# +-----+---+-------+
# | 118 | 3 | 0.375 |
# +-----+---+-------+
# | 119 | 4 | 0.5   |
# +-----+---+-------+
# | 120 | 5 | 0.625 |
# +-----+---+-------+
# | 121 | 6 | 0.75  |
# +-----+---+-------+
# | 122 | 7 | 0.875 |
# +-----+---+-------+
# | 123 | 0 | 0     |
# +-----+---+-------+
# | 124 | 1 | 0.125 |
# +-----+---+-------+
# | 125 | 2 | 0.25  |
# +-----+---+-------+
# | 126 | 3 | 0.375 |
# +-----+---+-------+
# | 127 | 4 | 0.5   |
# +-----+---+-------+
# | 128 | 5 | 0.625 |
# +-----+---+-------+
# | 129 | 6 | 0.75  |
# +-----+---+-------+
# | 130 | 7 | 0.875 |
# +-----+---+-------+
# | 131 | 0 | 0     |
# +-----+---+-------+
# | 132 | 1 | 0.125 |
# +-----+---+-------+
# | 133 | 2 | 0.25  |
# +-----+---+-------+
# | 134 | 3 | 0.375 |
# +-----+---+-------+
# | 135 | 4 | 0.5   |
# +-----+---+-------+
# | 136 | 5 | 0.625 |
# +-----+---+-------+
# | 137 | 6 | 0.75  |
# +-----+---+-------+
# | 138 | 7 | 0.875 |
# +-----+---+-------+
# | 139 | 0 | 0     |
# +-----+---+-------+
# | 140 | 1 | 0.125 |
# +-----+---+-------+
# | 141 | 2 | 0.25  |
# +-----+---+-------+
# | 142 | 3 | 0.375 |
# +-----+---+-------+
# | 143 | 4 | 0.5   |
# +-----+---+-------+
# | 144 | 5 | 0.625 |
# +-----+---+-------+
# | 145 | 6 | 0.75  |
# +-----+---+-------+
# | 146 | 7 | 0.875 |
# +-----+---+-------+
# | 147 | 0 | 0     |
# +-----+---+-------+
# | 148 | 1 | 0.125 |
# +-----+---+-------+
# | 149 | 2 | 0.25  |
# +-----+---+-------+
# | 150 | 3 | 0.375 |
# +-----+---+-------+
# | 151 | 4 | 0.5   |
# +-----+---+-------+
# | 152 | 5 | 0.625 |
# +-----+---+-------+
# | 153 | 6 | 0.75  |
# +-----+---+-------+
# | 154 | 7 | 0.875 |
# +-----+---+-------+
# | 155 | 0 | 0     |
# +-----+---+-------+
# | 156 | 1 | 0.125 |
# +-----+---+-------+
# | 157 | 2 | 0.25  |
# +-----+---+-------+
# | 158 | 3 | 0.375 |
# +-----+---+-------+
# | 159 | 4 | 0.5   |
# +-----+---+-------+
# | 160 | 5 | 0.625 |
# +-----+---+-------+
# | 161 | 6 | 0.75  |
# +-----+---+-------+
# | 162 | 7 | 0.875 |
# +-----+---+-------+
# | 163 | 0 | 0     |
# +-----+---+-------+
# | 164 | 1 | 0.125 |
# +-----+---+-------+
# | 165 | 2 | 0.25  |
# +-----+---+-------+
# | 166 | 3 | 0.375 |
# +-----+---+-------+
# | 167 | 4 | 0.5   |
# +-----+---+-------+
# | 168 | 5 | 0.625 |
# +-----+---+-------+
# | 169 | 6 | 0.75  |
# +-----+---+-------+
# | 170 | 7 | 0.875 |
# +-----+---+-------+
# | 171 | 0 | 0     |
# +-----+---+-------+
# | 172 | 1 | 0.125 |
# +-----+---+-------+
# | 173 | 2 | 0.25  |
# +-----+---+-------+
# | 174 | 3 | 0.375 |
# +-----+---+-------+
# | 175 | 4 | 0.5   |
# +-----+---+-------+
# | 176 | 5 | 0.625 |
# +-----+---+-------+
# | 177 | 6 | 0.75  |
# +-----+---+-------+
# | 178 | 7 | 0.875 |
# +-----+---+-------+
# | 179 | 0 | 0     |
# +-----+---+-------+
# | 180 | 1 | 0.125 |
# +-----+---+-------+
# | 181 | 2 | 0.25  |
# +-----+---+-------+
# | 182 | 3 | 0.375 |
# +-----+---+-------+
# | 183 | 4 | 0.5   |
# +-----+---+-------+
# | 184 | 5 | 0.625 |
# +-----+---+-------+
# | 185 | 6 | 0.75  |
# +-----+---+-------+
# | 186 | 7 | 0.875 |
# +-----+---+-------+
# | 187 | 0 | 0     |
# +-----+---+-------+
# | 188 | 1 | 0.125 |
# +-----+---+-------+
# | 189 | 2 | 0.25  |
# +-----+---+-------+
# | 190 | 3 | 0.375 |
# +-----+---+-------+
# | 191 | 4 | 0.5   |
# +-----+---+-------+
# | 192 | 5 | 0.625 |
# +-----+---+-------+
# | 193 | 6 | 0.75  |
# +-----+---+-------+
# | 194 | 7 | 0.875 |
# +-----+---+-------+
# | 195 | 0 | 0     |
# +-----+---+-------+
# | 196 | 1 | 0.125 |
# +-----+---+-------+
# | 197 | 2 | 0.25  |
# +-----+---+-------+
# | 198 | 3 | 0.375 |
# +-----+---+-------+
# | 199 | 4 | 0.5   |
# +-----+---+-------+
# | 200 | 5 | 0.625 |
# +-----+---+-------+
# | 201 | 6 | 0.75  |
# +-----+---+-------+
# | 202 | 7 | 0.875 |
# +-----+---+-------+
# | 203 | 0 | 0     |
# +-----+---+-------+
# | 204 | 1 | 0.125 |
# +-----+---+-------+
# | 205 | 2 | 0.25  |
# +-----+---+-------+
# | 206 | 3 | 0.375 |
# +-----+---+-------+
# | 207 | 4 | 0.5   |
# +-----+---+-------+
# | 208 | 5 | 0.625 |
# +-----+---+-------+
# | 209 | 6 | 0.75  |
# +-----+---+-------+
# | 210 | 7 | 0.875 |
# +-----+---+-------+
# | 211 | 0 | 0     |
# +-----+---+-------+
# | 212 | 1 | 0.125 |
# +-----+---+-------+
# | 213 | 2 | 0.25  |
# +-----+---+-------+
# | 214 | 3 | 0.375 |
# +-----+---+-------+
# | 215 | 4 | 0.5   |
# +-----+---+-------+
# | 216 | 5 | 0.625 |
# +-----+---+-------+
# | 217 | 6 | 0.75  |
# +-----+---+-------+
# | 218 | 7 | 0.875 |
# +-----+---+-------+
# | 219 | 0 | 0     |
# +-----+---+-------+
# | 220 | 1 | 0.125 |
# +-----+---+-------+
# | 221 | 2 | 0.25  |
# +-----+---+-------+
# | 222 | 3 | 0.375 |
# +-----+---+-------+
# | 223 | 4 | 0.5   |
# +-----+---+-------+
# | 224 | 5 | 0.625 |
# +-----+---+-------+
# | 225 | 6 | 0.75  |
# +-----+---+-------+
# | 226 | 7 | 0.875 |
# +-----+---+-------+
# | 227 | 0 | 0     |
# +-----+---+-------+
# | 228 | 1 | 0.125 |
# +-----+---+-------+
# | 229 | 2 | 0.25  |
# +-----+---+-------+
# | 230 | 3 | 0.375 |
# +-----+---+-------+
# | 231 | 4 | 0.5   |
# +-----+---+-------+
# | 232 | 5 | 0.625 |
# +-----+---+-------+
# | 233 | 6 | 0.75  |
# +-----+---+-------+
# | 234 | 7 | 0.875 |
# +-----+---+-------+
# | 235 | 0 | 0     |
# +-----+---+-------+
# | 236 | 1 | 0.125 |
# +-----+---+-------+
# | 237 | 2 | 0.25  |
# +-----+---+-------+
# | 238 | 3 | 0.375 |
# +-----+---+-------+
# | 239 | 4 | 0.5   |
# +-----+---+-------+
# | 240 | 5 | 0.625 |
# +-----+---+-------+
# | 241 | 6 | 0.75  |
# +-----+---+-------+
# | 242 | 7 | 0.875 |
# +-----+---+-------+
# | 243 | 0 | 0     |
# +-----+---+-------+
# | 244 | 1 | 0.125 |
# +-----+---+-------+
# | 245 | 2 | 0.25  |
# +-----+---+-------+
# | 246 | 3 | 0.375 |
# +-----+---+-------+
# | 247 | 4 | 0.5   |
# +-----+---+-------+
# | 248 | 5 | 0.625 |
# +-----+---+-------+
# | 249 | 6 | 0.75  |
# +-----+---+-------+
# | 250 | 7 | 0.875 |
# +-----+---+-------+
# | 251 | 0 | 0     |
# +-----+---+-------+
# | 252 | 1 | 0.125 |
# +-----+---+-------+
# | 253 | 2 | 0.25  |
# +-----+---+-------+
# | 254 | 3 | 0.375 |
# +-----+---+-------+
# | 255 | 4 | 0.5   |
# +-----+---+-------+
# | 256 | 5 | 0.625 |
# +-----+---+-------+
# | 257 | 6 | 0.75  |
# +-----+---+-------+
# | 258 | 7 | 0.875 |
# +-----+---+-------+
# | 259 | 0 | 0     |
# +-----+---+-------+
# | 260 | 1 | 0.125 |
# +-----+---+-------+
# | 261 | 2 | 0.25  |
# +-----+---+-------+
# | 262 | 3 | 0.375 |
# +-----+---+-------+
# | 263 | 4 | 0.5   |
# +-----+---+-------+
# | 264 | 5 | 0.625 |
# +-----+---+-------+
# | 265 | 6 | 0.75  |
# +-----+---+-------+
# | 266 | 7 | 0.875 |
# +-----+---+-------+
# | 267 | 0 | 0     |
# +-----+---+-------+
# | 268 | 1 | 0.125 |
# +-----+---+-------+
# | 269 | 2 | 0.25  |
# +-----+---+-------+
# | 270 | 3 | 0.375 |
# +-----+---+-------+
# | 271 | 4 | 0.5   |
# +-----+---+-------+
# | 272 | 5 | 0.625 |
# +-----+---+-------+
# | 273 | 6 | 0.75  |
# +-----+---+-------+
# | 274 | 7 | 0.875 |
# +-----+---+-------+
# | 275 | 0 | 0     |
# +-----+---+-------+
# | 276 | 1 | 0.125 |
# +-----+---+-------+
# | 277 | 2 | 0.25  |
# +-----+---+-------+
# | 278 | 3 | 0.375 |
# +-----+---+-------+
