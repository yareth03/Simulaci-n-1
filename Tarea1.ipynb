# %% [markdown]
# <a href="https://colab.research.google.com/github/yareth03/Simulaci-n-1/blob/main/Tarea1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tabulate import tabulate
import matplotlib.pyplot as plt
def randomyare():
    xi = int(input("Escribe el valor inicial: "))
    a = int(input("Escribe el multiplicador constante: "))
    c = int(input("Escribe el incremento: "))
    m = int(input("Escribe el modulo: "))
    n = int(input("¿Cuántas iteraciones quieres? "))
    tabla = [ ]
    Lista = []
    p = 0
    xcero= ((a*xi+c)%m)/m

    for i in range(1, n + 1):

        xi = (a * xi + c) % m
        p = float(xi)
        tabla.append([i, xi, xi/m])
        Lista.append([xi/m])
        if xi/m == xcero:
            print("El tiempo de vida es: ",i)



    return tabla,n, Lista


tb, n, listaa = randomyare()
print(tabulate(tb, tablefmt="grid"))
plt.plot(listaa)
# Out:
# Escribe el valor inicial: 13
# Escribe el multiplicador constante: 17
# Escribe el incremento: 84
# Escribe el modulo: 45
# ¿Cuántas iteraciones quieres? 100
# El tiempo de vida es:  1
# El tiempo de vida es:  5
# El tiempo de vida es:  9
# El tiempo de vida es:  13
# El tiempo de vida es:  17
# El tiempo de vida es:  21
# El tiempo de vida es:  25
# El tiempo de vida es:  29
# El tiempo de vida es:  33
# El tiempo de vida es:  37
# El tiempo de vida es:  41
# El tiempo de vida es:  45
# El tiempo de vida es:  49
# El tiempo de vida es:  53
# El tiempo de vida es:  57
# El tiempo de vida es:  61
# El tiempo de vida es:  65
# El tiempo de vida es:  69
# El tiempo de vida es:  73
# El tiempo de vida es:  77
# El tiempo de vida es:  81
# El tiempo de vida es:  85
# El tiempo de vida es:  89
# El tiempo de vida es:  93
# El tiempo de vida es:  97
# +-----+----+-----------+
# |   1 | 35 | 0.777778  |
# +-----+----+-----------+
# |   2 |  4 | 0.0888889 |
# +-----+----+-----------+
# ...
