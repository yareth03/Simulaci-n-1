# %% [markdown]
# <a href="https://colab.research.google.com/github/yareth03/Simulaci-n-1/blob/main/aleahisto2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tabulate import tabulate
import numpy as np

import matplotlib.pyplot as plt
def randomyare():
  while True:
    xi = int(input("Escribe el valor inicial: "))
    a = int(input("Escribe el multiplicador constante: "))
    #if (a-1)%(2)
    c = int(input("Escribe el incremento: "))
    #m = int(input("Escribe el modulo: "))
    m= 100**2
    n = int(input("¿Cuántas iteraciones quieres? "))
    tabla = [ ]
    Lista = []
    p = 0
    xcero= ((a*xi+c)%m)/m







    for i in range(1, n + 1):

        xi = (a * xi + c) % m
        p = float(xi)
        tabla.append([i, xi, xi/m])
        Lista.append([xi/m])
        if xi/m == xcero:
            print("El tiempo de vida es: ",i)









    return tabla,n, Lista





tb, n, listaa = randomyare()
#print(tabulate(tb, tablefmt="grid"))



plt.plot(listaa)
plt.hist(listaa)




plt.show()
print ("La varianza es :", np.var(listaa))
print("La media es :", np.mean(listaa))
# Out:
# Escribe el valor inicial: 5
# Escribe el multiplicador constante: 81
# Escribe el incremento: 89
# ¿Cuántas iteraciones quieres? 10001
# El tiempo de vida es:  1
# El tiempo de vida es:  10001
# La varianza es : 0.08334529547095285
# La media es : 0.4999049495050496
