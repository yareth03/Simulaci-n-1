# %% [markdown]
# <a href="https://colab.research.google.com/github/yareth03/Simulaci-n-1/blob/main/Cuadrado%20medio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tabulate import tabulate

def randomyare():
    # Solicitar un número extrictamentr de 4 dígitos
    while True:
        xi = input("Escribe un número de 4 dígitos : ")
        if len(xi) == 4 and xi.isdigit():
            numero = int(xi)
            break
        else:
            print("Error: La semilla debe ser un número de 4 dígitos.")

    # Solicitar número de iteraciones
    n = int(input("Escribe un número de iteraciones: "))

    tabla = []

    for i in range(n):
        numero = numero ** 2  # Elevar al cuadrado
        numero_str = str(numero).zfill(8)  # Convierte a cadena y rellenar con ceros si es necesario

        # Extraer los 4 dígitos centrales
        centro = numero_str[2:6]

        tabla.append([i + 1, centro])  # Agregamos dato a la tabla
        numero = int(centro)  # Convertir a entero para la siguiente iteración

    # Mostrar resultados en formato de tabla
    print(tabulate(tabla, headers=["Iteración", "Número"], tablefmt="grid"))


randomyare()
# Out:
# Escribe un número de 4 dígitos (semilla): 12678
# Error: La semilla debe ser un número de 4 dígitos.
# Escribe un número de 4 dígitos (semilla): 713
# Error: La semilla debe ser un número de 4 dígitos.
# Escribe un número de 4 dígitos (semilla): 1728
# Escribe un número de iteraciones: 1820
# +-------------+----------+
# |   Iteración |   Número |
# +=============+==========+
# |           1 |     9859 |
# +-------------+----------+
# |           2 |     1998 |
# +-------------+----------+
# |           3 |     9920 |
# +-------------+----------+
# |           4 |     4064 |
# +-------------+----------+
# |           5 |     5160 |
# +-------------+----------+
# |           6 |     6256 |
# +-------------+----------+
# |           7 |     1375 |
# +-------------+----------+
# |           8 |     8906 |
# +-------------+----------+
# |           9 |     3168 |
# +-------------+----------+
# |          10 |     0362 |
# +-------------+----------+
# |          11 |     1310 |
# ...
